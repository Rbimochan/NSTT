# %% [markdown]
# # NSTT — Error Analysis (T-005)
#
# Produces qualitative ref/hyp samples and error-category breakdown for the report's Results & Discussion section.
#
# **Prerequisites:** T-003 checkpoint + T-004 evaluation pipeline.

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
import os, sys
from pathlib import Path

PROJECT_ROOT = Path("/content/drive/MyDrive/NSTT")
if not PROJECT_ROOT.exists():
    PROJECT_ROOT = Path("/content/NSTT")
sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)

# %%
# !pip install -q -r requirements.txt

# %%
import torch
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
CHECKPOINT_DIR = PROJECT_ROOT / "models" / "whisper-small-ne"
MAX_SAMPLES = None  # int for smoke test

# %%
from src.error_analysis import run_error_analysis

result = run_error_analysis(
    PROJECT_ROOT,
    CHECKPOINT_DIR,
    device=DEVICE,
    max_samples=MAX_SAMPLES,
)
print(result["category_counts"])

# %%
from pathlib import Path
for name in ["error_samples.md", "error_categories.md"]:
    print(Path("reports") / name)
    print((Path("reports") / name).read_text(encoding="utf-8")[:2000])
